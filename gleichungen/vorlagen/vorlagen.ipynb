# %% [markdown]
# ### 02 Polynomdivision

# %%
# Erarbeitung A1

var('x')
e = x^3-10*x^2+31*x-30
solve(e,x)
# Out:
# [x == 2, x == 3, x == 5]

# %%
# A2
e = x^3+8*x^2-5*x-84
solve(e,x)
# Out:
# [x == -7, x == -4, x == 3]

# %%
# A3
e = 2*x^4-9*x^3-10*x^2+27*x-10
solve(e,x)
# Out:
# [x == (1/2), x == -2, x == 1, x == 5]

# %%
# A4
e = 2*x^4-26*x^2+72
solve(e,x)
# Out:
# [x == -2, x == 2, x == -3, x == 3]

# %%
# Polynomdivision A1a
p(x) = 5*x^3 + 21*x^2 - 56*x - 12
q(x) = x+6
p.maxima_methods().divide(q)
# Out:
# [5*x^2 - 9*x - 2, 0]

# %%
# Polynomdivision A2a
p(x) = 3*x^3-15*x^2-36*x+108
q(x) = x-2
p.maxima_methods().divide(q)
# Out:
# [3*x^2 - 9*x - 54, 0]

# %%
p(x)/3
# Out:
# x^3 - 5*x^2 - 12*x + 36

# %%
# Polynomdivision A2b
p(x) = 2*x^4-9*x^3-10*x^2+27*x-10
solve(p(x),x)
# Out:
# [x == (1/2), x == -2, x == 1, x == 5]

# %%
# A3
f(x) = 5*x^6-42*x^5+165/2*x^4+70*x^3-180*x^2
plot(f(x),(x,-1.5,4.5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# A5a
var('x')
f(x) = (x^2-2*x+1)/(x-3)
plot([f(x),(x+1),(4/(x-3))],(x,-10,15),ymin=-50,ymax=50)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
# A5b
var('x')
f(x) = (x^2+x-6)/(x+2)
plot([f(x),(x-1),(-4/(x+2))],(x,-6,2),ymin=-50,ymax=50)
# Out:
# Graphics object consisting of 3 graphics primitives
