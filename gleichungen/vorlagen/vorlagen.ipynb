# %% [markdown]
# ### 02 Polynomdivision

# %%
# Erarbeitung A1

var('x')
e = x^3-10*x^2+31*x-30
solve(e,x)
# Out:
# [x == 2, x == 3, x == 5]

# %%
# A2
e = x^3+8*x^2-5*x-84
solve(e,x)
# Out:
# [x == -7, x == -4, x == 3]

# %%
# A3
e = 2*x^4-9*x^3-10*x^2+27*x-10
solve(e,x)
# Out:
# [x == (1/2), x == -2, x == 1, x == 5]

# %%
# A4
e = 2*x^4-26*x^2+72
solve(e,x)
# Out:
# [x == -2, x == 2, x == -3, x == 3]

# %%
# Polynomdivision A1a
p(x) = 5*x^3 + 21*x^2 - 56*x - 12
q(x) = x+6
p.maxima_methods().divide(q)
# Out:
# [5*x^2 - 9*x - 2, 0]

# %%
# Polynomdivision A2a
p(x) = 3*x^3-15*x^2-36*x+108
q(x) = x-2
p.maxima_methods().divide(q)
# Out:
# [3*x^2 - 9*x - 54, 0]

# %%
p(x)/3
# Out:
# x^3 - 5*x^2 - 12*x + 36

# %%
# Polynomdivision A2b
p(x) = 2*x^4-9*x^3-10*x^2+27*x-10
solve(p(x),x)
# Out:
# [x == (1/2), x == -2, x == 1, x == 5]

# %%
# A3
f(x) = 5*x^6-42*x^5+165/2*x^4+70*x^3-180*x^2
plot(f(x),(x,-1.5,4.5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# A5a
var('x')
f(x) = (x^2-2*x+1)/(x-3)
plot([f(x),(x+1),(4/(x-3))],(x,-10,15),ymin=-50,ymax=50)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
# A5b
var('x')
f(x) = (x^2+x-6)/(x+2)
plot([f(x),(x-1),(-4/(x+2))],(x,-6,2),ymin=-50,ymax=50)
# Out:
# Graphics object consisting of 3 graphics primitives

# %% [markdown]
# ### 03 Bruchgleichungen

# %%
var('x')
e = 3/(x-4) - 24/(x^2-16) - (3/(x+4) - x^2 + 16)
solve(e,x)
# Out:
# [x == -4, x == 4]

# %% [markdown]
# ### 04 Aequivalenzumformungen

# %%
var('x')
e = 4-x^2 < 5-2*x
solve(e,x)
# Out:
# [[x < 1], [x > 1]]

# %% [markdown]
# ### 05 Bruchungleichungen

# %%
#A1a
var('x')
f(x) = 8/(x-3)
g(x) = 4
plot([f(x),g(x)],(x,-2,7),ymin=-20,ymax=30)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A1b
var('x')
f(x) = 2/(x^2+3)
g(x) = 4/6
plot([f(x),g(x)],(x,-5,5),ymin=-0.2,ymax=1)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A1c
var('x')
f(x) = 4/(x-1)-3
g(x) = 2*x-1
plot([f(x),g(x)],(x,-5,5),ymin=-8,ymax=8)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2a
var('x')
f(x) = 1/(x-1)
g(x) = 5/(x-1)^2
plot([f(x),g(x)],(x,-5,10),ymin=-2,ymax=2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2b
var('x')
f(x) = x/(x-1)
g(x) = 1/x
plot([f(x),g(x)],(x,-10,10),ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2c
var('x')
f(x) = x/(x+3)
g(x) = (5*x+1)/(2*x)
plot([f(x),g(x)],(x,-10,10),ymin=-5,ymax=5)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2d
var('x')
f(x) = 2*x/(x+4)
g(x) = (x+1)/(x-2)
plot([f(x),g(x)],(x,-20,20),ymin=-10,ymax=10)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#A2e
var('x')
f(x) = 3/(x+2)
g(x) = 6*x/(x-1)
plot([f(x),g(x)],(x,-8,10),ymin=-5,ymax=10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2f
var('x')
f(x) = 4/(x+1)
g(x) = 2*x/(x+3)
plot([f(x),g(x)],(x,-10,5),ymin=-5,ymax=10)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2g
var('x')
f(x) = 2/(-x+2)
g(x) = (3*x+1)/(4*x+1)
plot([f(x),g(x)],(x,-4,5),ymin=-2,ymax=3)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### Betragsungleichungen

# %%
var('x')
f(x) = abs(x)
g(x) = abs(x-2)
h(x) = abs(1/2*x)
plot([f(x),g(x),h(x)],(x,-5,5),ymin=-0.5,ymax=3)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
var('x')
f(x) = abs(x)
g(x) = abs(2*x)
h(x) = abs(2*x+4)
i(x) = abs(2*x)+4
plot([f(x),g(x),h(x),i(x)],(x,-4,3),ymin=0,ymax=6)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
var('x')
f(x) = abs(x+2)
g(x) = abs(-3*x+6)
plot([f(x),g(x)],(x,-4,5),ymin=0,ymax=7,gridlines=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
var('x')
f(x) = abs(x+2)
g(x) = abs(x-3)
plot([f(x),g(x)],(x,-4,5),ymin=0,ymax=7,gridlines=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2a
var('x')
f(x) = abs(2*x+3)
g(x) = 6
plot([f(x),g(x)],(x,-7,5),ymin=0,ymax=7,gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2b
var('x')
f(x) = abs(2*x+4)
g(x) = abs(x)
plot([f(x),g(x)],(x,-7,5),ymin=0,ymax=7,gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2c
var('x')
f(x) = abs(x-1)
g(x) = 3-x
plot([f(x),g(x)],(x,-3,6),ymin=-2,ymax=5,gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2d
var('x')
f(x) = abs(2*x+6)
g(x) = abs(3-5*x)
plot([f(x),g(x)],(x,-5,4),ymin=0,ymax=8,gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A2e
var('x')
f(x) = abs(3+2*x)
g(x) = 5-3*abs(x)
plot([f(x),g(x)],(x,-4,3),ymin=-2,ymax=7,gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A3a
f(x) = abs(x-2)+abs(4-x)
g(x) = x+1
plot([f(x),g(x)],(x,-2,12),ymin=-2,ymax=10,gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A3b
f(x) = 2*abs(1-3*x) 
g(x) = 2+abs(3*x+8)
plot([f(x),g(x)],(x,-2,6),ymin=-2,ymax=25,gridlines=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A3c
f(x) = abs(x-6) 
g(x) = 2*x-abs(4-3*x)
plot([f(x),g(x)],(x,-1,7),ymin=-2,ymax=8,gridlines=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#A3d
f(x) = abs(3*x+6)+2*x
g(x) = 8-3*abs(3*x+2)
plot([f(x),g(x)],(x,-4,2),ymin=-6,ymax=10,gridlines=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### 08 Wurzelungleichungen

# %%
#Erarbeitung
f(x) = sqrt(x+7)
g(x) = x-5
plot([f(x),g(x)],(x,-7,10),ymin=-6,ymax=10,gridlines=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Erarbeitung
f(x) = -2*x+11
g(x) = sqrt(-2*x+11)
plot([f(x),g(x)],(x,-7,10),ymin=-6,ymax=10,gridlines=True)
# Out:
# verbose 0 (3835: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 54 points.
# verbose 0 (3835: plot.py, generate_plot_points) Last error message: 'Unable to compute f(10.0)'
# Graphics object consisting of 2 graphics primitives

# %%
f(x) = -2*x+4
g(x) = sqrt(f)
plot([f(x),g(x)],(x,-10,10),ymin=-1,ymax=5,gridlines=True)
# Out:
# verbose 0 (3835: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 81 points.
# verbose 0 (3835: plot.py, generate_plot_points) Last error message: 'Unable to compute f(10.0)'
# Graphics object consisting of 2 graphics primitives

# %% [markdown]
# ### 09 Betragsungleichungen in zwei Variablen

# %%
#1a
var("x y")
#implicit_plot(abs(x)+3*abs(y)-6, (x,-7,7), (y,-3,3),fill=True,fillcolor='white')
implicit_plot(abs(x)+3*abs(y)-6, (x,-7,7), (y,-3,3),axes=True, frame=False)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#1b
var("x y")
implicit_plot(abs(x-1)+abs(2*y)-4, (x,-4,6), (y,-3,3),axes=True, frame=False, gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#2a
var("x y")
f = abs(x/2)+abs(y)==1
region_plot(f, (x,-7,3), (y,-4,5),axes=True, frame=False,  gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#2b
var("x y")
f = abs(x/2)+abs(y/3)==1
region_plot(f, (x,-7,3), (y,-4,5),axes=True, frame=False,  gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#2c
var("x y")
f = abs((x+4)/2)+abs(y/3)==1
region_plot(f, (x,-7,3), (y,-4,5),axes=True, frame=False,  gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#2d
var("x y")
f = abs((x+4)/2)+abs((y-1)/3)==1
region_plot(f, (x,-7,3), (y,-4,5),axes=True, frame=False,  gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#3a
var("x y")
f = abs(x-2)+abs(y/3)<=1
region_plot(f,(x,-1,4),(y,-3,3),bordercol='black',incol='yellow',gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#3b
var("x y")
f = abs((x+1)/3)+abs((y-2)/4)>=1
region_plot(f,(x,-4,2),(y,-2,6),bordercol='black',incol='yellow',gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#3c
var("x y")
f = 2*abs(x+1)+abs(y-2)>=6
region_plot(f,(x,-4,2),(y,-4,8),bordercol='black',incol='yellow',gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#3d
var("x y")
f = 5*abs(x-2)+2*abs(y-5)<2
region_plot(f,(x,0,3),(y,0,6),bordercol='black',incol='yellow',gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#4a
var("x y")
f = x^2+y^2==1
region_plot(f,(x,-2,2),(y,-2,2),bordercol='black',incol='yellow',gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#4b
var("x y")
f = x^2+y^2<=9
region_plot(f,(x,-4,4),(y,-4,4),bordercol='black',incol='yellow',gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#4c
var("x y")
f = (x/2)^2+(y/3)^2<=1
region_plot(f,(x,-3,3),(y,-3,3),bordercol='black',incol='yellow',gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#4d
var("x y")
f = (x-2)^2/4+(y-1)^2/9<=1
region_plot(f,(x,-1,5),(y,-2,4),bordercol='black',incol='yellow',gridlines=True,ticks= [1,1])
# Out:
# Graphics object consisting of 2 graphics primitives
